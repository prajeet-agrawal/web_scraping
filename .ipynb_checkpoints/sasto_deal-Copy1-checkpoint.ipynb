# %%
import requests
from bs4 import BeautifulSoup
import csv

base_url = "https://www.sastodeal.com/sastodeal/cta-travel-packages-451"
response = requests.get(base_url)

soup = BeautifulSoup(response.content, 'lxml')
csv_file = open('sasto_deal.csv', 'w')
csv_writer = csv.writer(csv_file)
csv_writer.writerow(['S.no.','Product','Price'])

for table in soup.find_all(class_='prod-detail'):
    sn = table.find('b', class_="title").text
    print(product_name)
    
    product_name = table.find('b', class_="title").text
    print(product_name)

    price = table.find(class_="mrp offer-price").text
    print(price)
    
    print()
    
    csv_writer.writerow([sn,product_name, price])
    
csv_file.close()
# Out:
# Kathmandu Paragliding (Paragliding Only)
#
# रू 5500
#
#
# Kathmandu Paragliding (Paragliding + Photo + Video)
#
# रू 7000
#
#
# Kathmandu Paragliding For Nepali(Paragliding + Photo + Video + Transportation)
#
# रू 6500
#
#
# Valentine's Day Special Unbeatable Paragliding Coupon For Couple
#
# रू 12999
#
#
# 5 Night 6 Days Mumbai Goa Mumbai Holiday Tour
#
# रू 22575
#
#
# 5 Night 6 Days Agra Jaipur Delhi 6 Days Tour Package
#
# रू 22575
#
#
# Bangkok -Pattaya Holiday Package ( 4 Nights - 5 Days)
#
# रू 42999
#
#
# 4 Night 5 Days Bangkok Pattaya Exciting Tour Package On 25th Nov 2019
#
# रू 50000
#
#
# 4 Night 5 Days Bangkok Pattaya Exciting Tour Package On 11th Nov 2019
#
# रू 51000
#
#
# 4 Night 5 Days Bangkok Pattaya Exciting Tour Package On 30th Sept 2019
#
# रू 52000
#
#
# 4 Night 5 Days Bangkok Pattaya Exciting Tour Package On 25th Oct 2019
#
# रू 52000
#
#
# 4 Night 5 Days Bangkok Pattaya Exciting Tour Package On 7th Oct 2019
#
# रू 56000
#
#
# 4 Night 5 Days Bangkok Pattaya Exciting Tour Package On 11th Oct 2019
#
# रू 56000
#
#
# 4 Night 5 Days Bangkok Pattaya Exciting Tour Package On 2nd Oct 2019
#
# रू 56000
#
#
# 4 Night 5 Days Bangkok Pattaya Exciting Tour Package On 21th Oct 2019
#
# रू 56000
#
#
# Dubai Holiday Package
#
# रू 67999
#
#
# Bali Holiday Package ( 4 Nights - 5 Days )
#
# रू 74999
#
#
# 4 Night 5 Days Exciting Bali Tour Package On 22nd September 2019
#
# रू 75999
#
#
# 4 Night 5 Days Exciting Bali Tour Package On 8th December 2019
#
# रू 80999
#
#
# 4 Night 5 Days Exciting Bali Tour Package On 15th December 2019
#
# रू 80999
#
#
# 4 Night 5 Days Dubai Tour On 6th October 2019
#
# रू 85000
#
#
# 4 Night 5 Days Dubai Tour On 10th October 2019
#
# रू 85000
#
#
# 4 Night 5 Days Exciting Bali Tour Package On 22nd December 2019
#
# रू 85999
#
#
# 4 Night 5 Days Exciting Bali Tour Package On 29th December 2019
#
# रू 85999
